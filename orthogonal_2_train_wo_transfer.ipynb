# %%
import numpy as np
# Importing Pandas Library 
import pandas as pd
import matplotlib.pyplot as plt
from preprocessing import *
import os
import joblib
from sklearn.preprocessing import MinMaxScaler
from utils import *

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Activation, Reshape, Concatenate

from models.EEGNet import *

from sklearn.metrics import confusion_matrix

from preprocessing import *
# Out:
# 2024-10-07 16:11:40.187913: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-07 16:11:40.194663: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-07 16:11:40.202172: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-07 16:11:40.204618: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-07 16:11:40.210601: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-07 16:11:40.602774: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
label_name = ['eyebrows', 'left', 'right', 'both', 'teeth']
models = []
scalers = {}

for label in label_name:
    _model = load_model(rf'./pipeline_{label}/checkpoints/checkpoint.keras')
    _model.trainable = True
    _model = Model(inputs=_model.input, outputs=_model.layers[-4].output, name=label)
    print(_model.summary())
    models.append(_model)

    scalers[label] = joblib.load(rf'./pipeline_{label}/checkpoints/scaler.save')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728292300.928746   15712 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728292300.954732   15712 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728292300.960692   15712 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728292300.965939   15712 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728292300.971693   15712 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728292300.975238   15712 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728292301.095509   15712 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728292301.097019   15712 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1728292301.098396   15712 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-07 16:11:41.099803: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21018 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "eyebrows"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 4, 128, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 4, 128, 16)     │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 4, 128, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ depthwise_conv2d                │ (None, 1, 128, 48)     │           192 │
# │ (DepthwiseConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1, 128, 48)     │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 1, 128, 48)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 1, 32, 48)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1, 32, 48)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d                │ (None, 1, 32, 16)      │         1,536 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1, 32, 16)      │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 1, 32, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 1, 4, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1, 4, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,848 (11.12 KB)
#  Trainable params: 2,688 (10.50 KB)
#  Non-trainable params: 160 (640.00 B)
# None
# Model: "left"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 4, 128, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 4, 128, 16)     │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 4, 128, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ depthwise_conv2d                │ (None, 1, 128, 48)     │           192 │
# │ (DepthwiseConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1, 128, 48)     │           192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 1, 128, 48)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 1, 32, 48)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1, 32, 48)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d                │ (None, 1, 32, 16)      │         1,536 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1, 32, 16)      │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 1, 32, 16)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 1, 4, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1, 4, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,848 (11.12 KB)
#  Trainable params: 2,688 (10.50 KB)
#  Non-trainable params: 160 (640.00 B)
# None
# Model: "right"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 4, 128, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 4, 128, 10)     │           400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 4, 128, 10)     │            40 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ depthwise_conv2d                │ (None, 1, 128, 20)     │            80 │
# │ (DepthwiseConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1, 128, 20)     │            80 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 1, 128, 20)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 1, 32, 20)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1, 32, 20)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d                │ (None, 1, 32, 10)      │           520 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1, 32, 10)      │            40 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 1, 32, 10)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 1, 4, 10)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1, 4, 10)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 40)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,160 (4.53 KB)
#  Trainable params: 1,080 (4.22 KB)
#  Non-trainable params: 80 (320.00 B)
# None
# Model: "both"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 4, 128, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 4, 128, 32)     │         1,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 4, 128, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ depthwise_conv2d                │ (None, 1, 128, 192)    │           768 │
# │ (DepthwiseConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1, 128, 192)    │           768 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 1, 128, 192)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 1, 32, 192)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1, 32, 192)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d                │ (None, 1, 32, 32)      │         9,216 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1, 32, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 1, 32, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 1, 4, 32)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 128)            │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,608 (49.25 KB)
#  Trainable params: 12,096 (47.25 KB)
#  Non-trainable params: 512 (2.00 KB)
# None
# Model: "teeth"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 4, 128, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 4, 128, 32)     │         3,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 4, 128, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ depthwise_conv2d                │ (None, 1, 128, 128)    │           512 │
# │ (DepthwiseConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1, 128, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 1, 128, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 1, 32, 128)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1, 32, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d                │ (None, 1, 32, 32)      │         6,144 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 1, 32, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 1, 32, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_1             │ (None, 1, 4, 32)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1, 4, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 128)            │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,624 (41.50 KB)
#  Trainable params: 10,240 (40.00 KB)
#  Non-trainable params: 384 (1.50 KB)
# None

# %%
inputs = []
for label in label_name:
    inputs.append(
        Input(shape=(4, 128, 1), name=f"{label} input")
    )

# %%
outs = []
for i in range(len(label_name)):
    model = models[i]
    input = inputs[i]

    outs.append(model(input))

x = Concatenate()(outs)
x = Dense(128*6, activation='relu')(x)
x = Reshape((128, 6))(x)
x = Activation('softmax', name = 'softmax')(x)

model = Model(inputs=inputs, outputs=x)
model.summary()

model.compile(
    loss='sparse_categorical_crossentropy', 
    optimizer='adam',
    metrics=['accuracy']
)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ eyebrows input      │ (None, 4, 128, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ left input          │ (None, 4, 128, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ right input         │ (None, 4, 128, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ both input          │ (None, 4, 128, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ teeth input         │ (None, 4, 128, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ eyebrows            │ (None, 64)        │      2,848 │ eyebrows          │
# │ (Functional)        │                   │            │ input[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ left (Functional)   │ (None, 64)        │      2,848 │ left input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ right (Functional)  │ (None, 40)        │      1,160 │ right input[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ both (Functional)   │ (None, 128)       │     12,608 │ both input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ teeth (Functional)  │ (None, 128)       │     10,624 │ teeth input[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 424)       │          0 │ eyebrows[0][0],   │
# │ (Concatenate)       │                   │            │ left[0][0],       │
# │                     │                   │            │ right[0][0],      │
# │                     │                   │            │ both[0][0],       │
# │                     │                   │            │ teeth[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 768)       │    326,400 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 128, 6)    │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ softmax             │ (None, 128, 6)    │          0 │ reshape[0][0]     │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 356,488 (1.36 MB)
#  Trainable params: 355,192 (1.35 MB)
#  Non-trainable params: 1,296 (5.06 KB)

# %%
raw_data = {}
trial_num = 10
for label in label_name:
    raw_data[label] = {}
    for trial in range(1, trial_num + 1):
        raw_data[label][len(raw_data[label])] = [
            rf'./raw_data/{label}/{label}_{trial}.csv',
            rf'./roi_v2/{label}/{label}_{trial}.csv'
        ]
    
raw_data
# Out:
# {'eyebrows': {0: ['./raw_data/eyebrows/eyebrows_1.csv',
#    './roi_v2/eyebrows/eyebrows_1.csv'],
#   1: ['./raw_data/eyebrows/eyebrows_2.csv',
#    './roi_v2/eyebrows/eyebrows_2.csv'],
#   2: ['./raw_data/eyebrows/eyebrows_3.csv',
#    './roi_v2/eyebrows/eyebrows_3.csv'],
#   3: ['./raw_data/eyebrows/eyebrows_4.csv',
#    './roi_v2/eyebrows/eyebrows_4.csv'],
#   4: ['./raw_data/eyebrows/eyebrows_5.csv',
#    './roi_v2/eyebrows/eyebrows_5.csv'],
#   5: ['./raw_data/eyebrows/eyebrows_6.csv',
#    './roi_v2/eyebrows/eyebrows_6.csv'],
#   6: ['./raw_data/eyebrows/eyebrows_7.csv',
#    './roi_v2/eyebrows/eyebrows_7.csv'],
#   7: ['./raw_data/eyebrows/eyebrows_8.csv',
#    './roi_v2/eyebrows/eyebrows_8.csv'],
#   8: ['./raw_data/eyebrows/eyebrows_9.csv',
#    './roi_v2/eyebrows/eyebrows_9.csv'],
#   9: ['./raw_data/eyebrows/eyebrows_10.csv',
#    './roi_v2/eyebrows/eyebrows_10.csv']},
#  'left': {0: ['./raw_data/left/left_1.csv', './roi_v2/left/left_1.csv'],
#   1: ['./raw_data/left/left_2.csv', './roi_v2/left/left_2.csv'],
#   2: ['./raw_data/left/left_3.csv', './roi_v2/left/left_3.csv'],
#   3: ['./raw_data/left/left_4.csv', './roi_v2/left/left_4.csv'],
#   4: ['./raw_data/left/left_5.csv', './roi_v2/left/left_5.csv'],
#   5: ['./raw_data/left/left_6.csv', './roi_v2/left/left_6.csv'],
#   6: ['./raw_data/left/left_7.csv', './roi_v2/left/left_7.csv'],
#   7: ['./raw_data/left/left_8.csv', './roi_v2/left/left_8.csv'],
#   8: ['./raw_data/left/left_9.csv', './roi_v2/left/left_9.csv'],
#   9: ['./raw_data/left/left_10.csv', './roi_v2/left/left_10.csv']},
#  'right': {0: ['./raw_data/right/right_1.csv', './roi_v2/right/right_1.csv'],
#   1: ['./raw_data/right/right_2.csv', './roi_v2/right/right_2.csv'],
#   2: ['./raw_data/right/right_3.csv', './roi_v2/right/right_3.csv'],
#   3: ['./raw_data/right/right_4.csv', './roi_v2/right/right_4.csv'],
#   4: ['./raw_data/right/right_5.csv', './roi_v2/right/right_5.csv'],
#   5: ['./raw_data/right/right_6.csv', './roi_v2/right/right_6.csv'],
#   6: ['./raw_data/right/right_7.csv', './roi_v2/right/right_7.csv'],
#   7: ['./raw_data/right/right_8.csv', './roi_v2/right/right_8.csv'],
#   8: ['./raw_data/right/right_9.csv', './roi_v2/right/right_9.csv'],
#   9: ['./raw_data/right/right_10.csv', './roi_v2/right/right_10.csv']},
#  'both': {0: ['./raw_data/both/both_1.csv', './roi_v2/both/both_1.csv'],
#   1: ['./raw_data/both/both_2.csv', './roi_v2/both/both_2.csv'],
#   2: ['./raw_data/both/both_3.csv', './roi_v2/both/both_3.csv'],
#   3: ['./raw_data/both/both_4.csv', './roi_v2/both/both_4.csv'],
#   4: ['./raw_data/both/both_5.csv', './roi_v2/both/both_5.csv'],
#   5: ['./raw_data/both/both_6.csv', './roi_v2/both/both_6.csv'],
#   6: ['./raw_data/both/both_7.csv', './roi_v2/both/both_7.csv'],
#   7: ['./raw_data/both/both_8.csv', './roi_v2/both/both_8.csv'],
#   8: ['./raw_data/both/both_9.csv', './roi_v2/both/both_9.csv'],
#   9: ['./raw_data/both/both_10.csv', './roi_v2/both/both_10.csv']},
#  'teeth': {0: ['./raw_data/teeth/teeth_1.csv', './roi_v2/teeth/teeth_1.csv'],
#   1: ['./raw_data/teeth/teeth_2.csv', './roi_v2/teeth/teeth_2.csv'],
#   2: ['./raw_data/teeth/teeth_3.csv', './roi_v2/teeth/teeth_3.csv'],
#   3: ['./raw_data/teeth/teeth_4.csv', './roi_v2/teeth/teeth_4.csv'],
#   4: ['./raw_data/teeth/teeth_5.csv', './roi_v2/teeth/teeth_5.csv'],
#   5: ['./raw_data/teeth/teeth_6.csv', './roi_v2/teeth/teeth_6.csv'],
#   6: ['./raw_data/teeth/teeth_7.csv', './roi_v2/teeth/teeth_7.csv'],
#   7: ['./raw_data/teeth/teeth_8.csv', './roi_v2/teeth/teeth_8.csv'],
#   8: ['./raw_data/teeth/teeth_9.csv', './roi_v2/teeth/teeth_9.csv'],
#   9: ['./raw_data/teeth/teeth_10.csv', './roi_v2/teeth/teeth_10.csv']}}

# %%
filters = {
    'left': filter_left,
    'right': filter_right,
    'both': filter_both,
    'teeth': filter_teeth,
    'eyebrows': filter_eyebrows,
}

# %%
dataset = {}
num = 1
for label_ in raw_data:
    data, label = process_raw_record_20_features(raw_data[label_])

    dataset[label_] = {}
    temp_data, temp_label = create_dataset_20_features(data, label, filters, scalers, epsilon=0.1)
    print(temp_data.shape, temp_label.shape)
    temp_label[temp_label == 1] = num
    num += 1

    temp_data, temp_label = unison_shuffled_copies(temp_data, temp_label)
    temp_data = temp_data[:30000]
    temp_label = temp_label[:30000]
    train_idx = int(temp_data.shape[0] * 0.8)
    dataset[label_]['train_data'] = temp_data[:train_idx]
    dataset[label_]['train_label'] = temp_label[:train_idx]
    dataset[label_]['test_data'] = temp_data[train_idx:]
    dataset[label_]['test_label'] = temp_label[train_idx:]

    print(
        label_, 
        dataset[label_]['train_data'].shape,
        dataset[label_]['train_label'].shape,
        dataset[label_]['test_data'].shape,
        dataset[label_]['test_label'].shape,
        sep=' --- '
    )
# Out:
# (36517, 128, 20) (36517, 128)
# eyebrows --- (24000, 128, 20) --- (24000, 128) --- (6000, 128, 20) --- (6000, 128)
# (31731, 128, 20) (31731, 128)
# left --- (24000, 128, 20) --- (24000, 128) --- (6000, 128, 20) --- (6000, 128)
# (31882, 128, 20) (31882, 128)
# right --- (24000, 128, 20) --- (24000, 128) --- (6000, 128, 20) --- (6000, 128)
# (36601, 128, 20) (36601, 128)
# both --- (24000, 128, 20) --- (24000, 128) --- (6000, 128, 20) --- (6000, 128)
# (35624, 128, 20) (35624, 128)
# teeth --- (24000, 128, 20) --- (24000, 128) --- (6000, 128, 20) --- (6000, 128)

# %%
train_x = []
train_y = []
test_x = []
test_y = []

for label in dataset:
    train_x.append(dataset[label]['train_data'])
    train_y.append(dataset[label]['train_label'])
    test_x.append(dataset[label]['test_data'])
    test_y.append(dataset[label]['test_label'])

train_x = np.concatenate(train_x)
train_y = np.concatenate(train_y)
test_x = np.concatenate(test_x)
test_y = np.concatenate(test_y)

# %%
train_x = train_x.transpose((0, 2, 1))
test_x = test_x.transpose((0, 2, 1))

train_x = np.expand_dims(train_x, axis=-1)
test_x = np.expand_dims(test_x, axis=-1)
print(train_x.shape, train_y.shape, test_x.shape, test_y.shape)

train_x, train_y = unison_shuffled_copies(train_x, train_y)
# Out:
# (120000, 20, 128, 1) (120000, 128) (30000, 20, 128, 1) (30000, 128)

# %%
np.savez_compressed(
    'train.npz', 
    train_x=train_x, 
    train_y=train_y, 
    test_x=test_x, 
    test_y=test_y
)

# %%
loaded_data = np.load('train.npz')
train_x = loaded_data['train_x']
train_y = loaded_data['train_y']
test_x = loaded_data['test_x']
test_y = loaded_data['test_y']

# %%
train_x.shape
# Out:
# (120000, 20, 128, 1)

# %%
history = model.fit(
    [
        train_x[:, :4], 
        train_x[:, 4:8], 
        train_x[:, 8:12],
        train_x[:, 12:16],
        train_x[:, 16:20]
    ], 
    train_y,
    epochs=100,
    validation_data=(
        [
            test_x[:, :4], 
            test_x[:, 4:8], 
            test_x[:, 8:12],
            test_x[:, 12:16],
            test_x[:, 16:20]
        ],
        test_y
    ),
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728292324.267609   15848 service.cc:146] XLA service 0x73384c0301e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728292324.267636   15848 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2024-10-07 16:12:04.349193: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-07 16:12:04.685062: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
#   22/3750 ━━━━━━━━━━━━━━━━━━━━ 30s 8ms/step - accuracy: 0.3734 - loss: 1.7010
# I0000 00:00:1728292329.778187   15848 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3748/3750 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9001 - loss: 0.2993
# W0000 00:00:1728292361.920282   15843 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# W0000 00:00:1728292363.677432   15848 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 42s 9ms/step - accuracy: 0.9001 - loss: 0.2992 - val_accuracy: 0.9446 - val_loss: 0.1511
# Epoch 2/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9389 - loss: 0.1719 - val_accuracy: 0.9471 - val_loss: 0.1481
# Epoch 3/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9413 - loss: 0.1641 - val_accuracy: 0.9509 - val_loss: 0.1287
# Epoch 4/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 9ms/step - accuracy: 0.9422 - loss: 0.1608 - val_accuracy: 0.9507 - val_loss: 0.1316
# Epoch 5/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9433 - loss: 0.1574 - val_accuracy: 0.9411 - val_loss: 0.1646
# Epoch 6/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - accuracy: 0.9436 - loss: 0.1558 - val_accuracy: 0.9506 - val_loss: 0.1307
# Epoch 7/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 30s 8ms/step - accuracy: 0.9443 - loss: 0.1536 - val_accuracy: 0.9526 - val_loss: 0.1238
# Epoch 8/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9449 - loss: 0.1510 - val_accuracy: 0.9529 - val_loss: 0.1238
# Epoch 9/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9444 - loss: 0.1522 - val_accuracy: 0.9459 - val_loss: 0.1472
# Epoch 10/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - accuracy: 0.9452 - loss: 0.1508 - val_accuracy: 0.9525 - val_loss: 0.1261
# Epoch 11/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - accuracy: 0.9455 - loss: 0.1495 - val_accuracy: 0.9536 - val_loss: 0.1213
# Epoch 12/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9464 - loss: 0.1473 - val_accuracy: 0.9559 - val_loss: 0.1148
# Epoch 13/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9463 - loss: 0.1465 - val_accuracy: 0.9530 - val_loss: 0.1250
# Epoch 14/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9469 - loss: 0.1451 - val_accuracy: 0.9505 - val_loss: 0.1376
# Epoch 15/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9467 - loss: 0.1452 - val_accuracy: 0.9549 - val_loss: 0.1170
# Epoch 16/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9471 - loss: 0.1441 - val_accuracy: 0.9565 - val_loss: 0.1131
# Epoch 17/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9475 - loss: 0.1427 - val_accuracy: 0.9574 - val_loss: 0.1105
# Epoch 18/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9480 - loss: 0.1419 - val_accuracy: 0.9561 - val_loss: 0.1169
# Epoch 19/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9481 - loss: 0.1413 - val_accuracy: 0.9557 - val_loss: 0.1150
# Epoch 20/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9478 - loss: 0.1415 - val_accuracy: 0.9577 - val_loss: 0.1083
# Epoch 21/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9486 - loss: 0.1389 - val_accuracy: 0.9577 - val_loss: 0.1101
# Epoch 22/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9481 - loss: 0.1412 - val_accuracy: 0.9581 - val_loss: 0.1076
# Epoch 23/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9487 - loss: 0.1392 - val_accuracy: 0.9565 - val_loss: 0.1138
# Epoch 24/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9482 - loss: 0.1403 - val_accuracy: 0.9586 - val_loss: 0.1066
# Epoch 25/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9491 - loss: 0.1378 - val_accuracy: 0.9557 - val_loss: 0.1170
# Epoch 26/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9486 - loss: 0.1392 - val_accuracy: 0.9570 - val_loss: 0.1116
# Epoch 27/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9488 - loss: 0.1383 - val_accuracy: 0.9581 - val_loss: 0.1086
# Epoch 28/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9489 - loss: 0.1383 - val_accuracy: 0.9572 - val_loss: 0.1104
# Epoch 29/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 32s 8ms/step - accuracy: 0.9494 - loss: 0.1375 - val_accuracy: 0.9516 - val_loss: 0.1313
# Epoch 30/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9494 - loss: 0.1372 - val_accuracy: 0.9581 - val_loss: 0.1088
# Epoch 31/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9495 - loss: 0.1370 - val_accuracy: 0.9593 - val_loss: 0.1051
# Epoch 32/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9496 - loss: 0.1360 - val_accuracy: 0.9587 - val_loss: 0.1065
# Epoch 33/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9496 - loss: 0.1357 - val_accuracy: 0.9577 - val_loss: 0.1099
# Epoch 34/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9498 - loss: 0.1354 - val_accuracy: 0.9580 - val_loss: 0.1086
# Epoch 35/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 9ms/step - accuracy: 0.9496 - loss: 0.1355 - val_accuracy: 0.9598 - val_loss: 0.1026
# Epoch 36/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 9ms/step - accuracy: 0.9497 - loss: 0.1357 - val_accuracy: 0.9592 - val_loss: 0.1052
# Epoch 37/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9497 - loss: 0.1354 - val_accuracy: 0.9563 - val_loss: 0.1142
# Epoch 38/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9500 - loss: 0.1346 - val_accuracy: 0.9566 - val_loss: 0.1129
# Epoch 39/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9498 - loss: 0.1351 - val_accuracy: 0.9556 - val_loss: 0.1145
# Epoch 40/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9504 - loss: 0.1333 - val_accuracy: 0.9594 - val_loss: 0.1038
# Epoch 41/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9502 - loss: 0.1338 - val_accuracy: 0.9596 - val_loss: 0.1039
# Epoch 42/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9499 - loss: 0.1352 - val_accuracy: 0.9601 - val_loss: 0.1013
# Epoch 43/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9499 - loss: 0.1345 - val_accuracy: 0.9563 - val_loss: 0.1135
# Epoch 44/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9503 - loss: 0.1337 - val_accuracy: 0.9589 - val_loss: 0.1058
# Epoch 45/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9506 - loss: 0.1326 - val_accuracy: 0.9570 - val_loss: 0.1121
# Epoch 46/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9507 - loss: 0.1322 - val_accuracy: 0.9586 - val_loss: 0.1061
# Epoch 47/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 9ms/step - accuracy: 0.9505 - loss: 0.1335 - val_accuracy: 0.9594 - val_loss: 0.1048
# Epoch 48/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9509 - loss: 0.1326 - val_accuracy: 0.9587 - val_loss: 0.1060
# Epoch 49/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 9ms/step - accuracy: 0.9511 - loss: 0.1314 - val_accuracy: 0.9568 - val_loss: 0.1132
# Epoch 50/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 9ms/step - accuracy: 0.9509 - loss: 0.1322 - val_accuracy: 0.9561 - val_loss: 0.1149
# Epoch 51/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9514 - loss: 0.1306 - val_accuracy: 0.9595 - val_loss: 0.1060
# Epoch 52/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9514 - loss: 0.1310 - val_accuracy: 0.9557 - val_loss: 0.1170
# Epoch 53/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9511 - loss: 0.1312 - val_accuracy: 0.9596 - val_loss: 0.1047
# Epoch 54/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9511 - loss: 0.1310 - val_accuracy: 0.9606 - val_loss: 0.1002
# Epoch 55/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - accuracy: 0.9512 - loss: 0.1307 - val_accuracy: 0.9585 - val_loss: 0.1067
# Epoch 56/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9514 - loss: 0.1306 - val_accuracy: 0.9594 - val_loss: 0.1054
# Epoch 57/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9513 - loss: 0.1310 - val_accuracy: 0.9595 - val_loss: 0.1046
# Epoch 58/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9509 - loss: 0.1316 - val_accuracy: 0.9581 - val_loss: 0.1075
# Epoch 59/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9516 - loss: 0.1299 - val_accuracy: 0.9596 - val_loss: 0.1031
# Epoch 60/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 9ms/step - accuracy: 0.9510 - loss: 0.1317 - val_accuracy: 0.9602 - val_loss: 0.1023
# Epoch 61/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9513 - loss: 0.1308 - val_accuracy: 0.9576 - val_loss: 0.1091
# Epoch 62/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9514 - loss: 0.1306 - val_accuracy: 0.9599 - val_loss: 0.1031
# Epoch 63/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 9ms/step - accuracy: 0.9516 - loss: 0.1291 - val_accuracy: 0.9587 - val_loss: 0.1070
# Epoch 64/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - accuracy: 0.9518 - loss: 0.1288 - val_accuracy: 0.9592 - val_loss: 0.1064
# Epoch 65/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9517 - loss: 0.1297 - val_accuracy: 0.9604 - val_loss: 0.1017
# Epoch 66/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9517 - loss: 0.1298 - val_accuracy: 0.9604 - val_loss: 0.1009
# Epoch 67/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9515 - loss: 0.1296 - val_accuracy: 0.9592 - val_loss: 0.1056
# Epoch 68/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9516 - loss: 0.1298 - val_accuracy: 0.9595 - val_loss: 0.1047
# Epoch 69/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9517 - loss: 0.1294 - val_accuracy: 0.9606 - val_loss: 0.1016
# Epoch 70/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9514 - loss: 0.1300 - val_accuracy: 0.9600 - val_loss: 0.1032
# Epoch 71/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9518 - loss: 0.1291 - val_accuracy: 0.9620 - val_loss: 0.0980
# Epoch 72/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9519 - loss: 0.1286 - val_accuracy: 0.9579 - val_loss: 0.1091
# Epoch 73/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9520 - loss: 0.1292 - val_accuracy: 0.9599 - val_loss: 0.1041
# Epoch 74/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9514 - loss: 0.1304 - val_accuracy: 0.9593 - val_loss: 0.1056
# Epoch 75/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9521 - loss: 0.1281 - val_accuracy: 0.9612 - val_loss: 0.0994
# Epoch 76/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9516 - loss: 0.1298 - val_accuracy: 0.9600 - val_loss: 0.1025
# Epoch 77/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 9ms/step - accuracy: 0.9519 - loss: 0.1292 - val_accuracy: 0.9621 - val_loss: 0.0965
# Epoch 78/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9520 - loss: 0.1285 - val_accuracy: 0.9613 - val_loss: 0.0987
# Epoch 79/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9522 - loss: 0.1281 - val_accuracy: 0.9572 - val_loss: 0.1121
# Epoch 80/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9521 - loss: 0.1281 - val_accuracy: 0.9613 - val_loss: 0.0984
# Epoch 81/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - accuracy: 0.9518 - loss: 0.1288 - val_accuracy: 0.9603 - val_loss: 0.1017
# Epoch 82/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9520 - loss: 0.1281 - val_accuracy: 0.9614 - val_loss: 0.0984
# Epoch 83/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 9ms/step - accuracy: 0.9525 - loss: 0.1268 - val_accuracy: 0.9592 - val_loss: 0.1062
# Epoch 84/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9519 - loss: 0.1290 - val_accuracy: 0.9608 - val_loss: 0.1006
# Epoch 85/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9522 - loss: 0.1281 - val_accuracy: 0.9594 - val_loss: 0.1053
# Epoch 86/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9517 - loss: 0.1291 - val_accuracy: 0.9611 - val_loss: 0.0995
# Epoch 87/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - accuracy: 0.9520 - loss: 0.1289 - val_accuracy: 0.9625 - val_loss: 0.0957
# Epoch 88/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9526 - loss: 0.1264 - val_accuracy: 0.9608 - val_loss: 0.1016
# Epoch 89/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - accuracy: 0.9523 - loss: 0.1272 - val_accuracy: 0.9615 - val_loss: 0.0978
# Epoch 90/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9523 - loss: 0.1278 - val_accuracy: 0.9599 - val_loss: 0.1024
# Epoch 91/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9529 - loss: 0.1261 - val_accuracy: 0.9593 - val_loss: 0.1049
# Epoch 92/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - accuracy: 0.9527 - loss: 0.1263 - val_accuracy: 0.9606 - val_loss: 0.1013
# Epoch 93/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9517 - loss: 0.1285 - val_accuracy: 0.9598 - val_loss: 0.1037
# Epoch 94/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9527 - loss: 0.1262 - val_accuracy: 0.9588 - val_loss: 0.1052
# Epoch 95/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - accuracy: 0.9522 - loss: 0.1280 - val_accuracy: 0.9617 - val_loss: 0.0980
# Epoch 96/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9521 - loss: 0.1286 - val_accuracy: 0.9621 - val_loss: 0.0969
# Epoch 97/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9528 - loss: 0.1263 - val_accuracy: 0.9599 - val_loss: 0.1028
# Epoch 98/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - accuracy: 0.9526 - loss: 0.1266 - val_accuracy: 0.9587 - val_loss: 0.1067
# Epoch 99/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 35s 9ms/step - accuracy: 0.9525 - loss: 0.1274 - val_accuracy: 0.9612 - val_loss: 0.0991
# Epoch 100/100
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - accuracy: 0.9526 - loss: 0.1265 - val_accuracy: 0.9598 - val_loss: 0.1040

# %%
plt.figure(figsize=(20, 10)).suptitle("All labels")
plt.subplot(121)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(122)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

# %%
y_pred = model.predict([
    test_x[:, :4], 
    test_x[:, 4:8], 
    test_x[:, 8:12],
    test_x[:, 12:16],
    test_x[:, 16:20]
])
y_true = test_y
y_pred = np.argmax(y_pred, 2)


cm_total = np.zeros((6, 6))

for y_t, y_p in zip(y_true, y_pred):
    cm = confusion_matrix(y_t, y_p, labels=[0, 1, 2, 3, 4, 5])
    cm = np.array(cm)
    cm_total = cm_total + cm


result = []
for cls in range(6):
    tp = cm_total[cls, cls]
    fn = np.sum(np.delete(cm_total[cls, :], cls))
    fp = np.sum(np.delete(cm_total[:, cls], cls))
    tn = np.delete(cm_total, cls, axis=0)
    tn = np.sum(np.delete(tn, cls, axis=1))

    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1 = (2 * precision * recall) / (precision + recall)
    acc = (tp + tn) / (tp + fn + tn + fp)
    specifity = tn/(tn+fp)

    result.append([precision, recall, f1, acc, specifity])

result = np.array(result)
# Out:
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
print(f'precision, recall, f1, acc, specifity\n{result}')
# Out:
# precision, recall, f1, acc, specifity
# [[0.98046836 0.95604328 0.96810178 0.95989609 0.966644  ]
#  [0.92365986 0.97160667 0.94702678 0.99488672 0.99603592]
#  [0.94575366 0.97471159 0.96001431 0.99091615 0.99295742]
#  [0.94286418 0.96961916 0.95605452 0.99093281 0.99334636]
#  [0.89126335 0.95055297 0.91995387 0.9896974  0.99229734]
#  [0.88786821 0.9527255  0.91915416 0.99320781 0.99491773]]

# %%
plt.figure(figsize=(20, 10))
plt.title("Confusion Matrix of All labels Detection Model")
plt.matshow(result, fignum=False)
plt.xticks([0, 1, 2, 3, 4], ['Positive Predictive\nValue (Precision)', 'True Positive\nRate (Recall)', 'F1 Score', 'Accuracy', 'True Negative\nRate (Specifity)'])
plt.yticks([0, 1, 2, 3, 4, 5], ['Not command', 'eyebrows', 'left', 'right', 'both', 'teeth'])
plt.xlabel("Metric")
plt.ylabel("Class")
for (i, j), z in np.ndenumerate(result):
    plt.text(j, i, '{:0.3f}'.format(z), ha='center', va='center')
plt.colorbar()

# %%
model.save(r'./checkpoints/orthogonal_2.keras')
